# %%
import numpy as np

path = '/nfs/nfs1/users/riadoshi/octo_files/files/exobs.npy'

# %%
obses = np.load(path, allow_pickle=True)

# %%
obses = obses.item(0)['image_primary']
obses.shape
# Out:
# (512, 2, 256, 256, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(obses[0][0])

# %%
obses.sh
